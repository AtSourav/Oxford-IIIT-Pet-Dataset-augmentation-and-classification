# %% [markdown]
# Training on the O dataset.

# %%
import torch
import skimage as ski
import numpy as np
from torch.utils.data import Dataset
import os
import pandas as pd
from torchvision.io import read_image
from torchvision import transforms as T
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn as nn
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Loading

# %%
class PetDataset(Dataset):
    def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
        self.img_annotations = pd.read_csv(annotations_file)
        self.img_dir = img_dir
        self.transform = transform
        self.target_transform = target_transform
        
    def __len__(self):
        return len(self.img_annotations)
    
    def __getitem__(self,idx):
        img_path = os.path.join(self.img_dir,self.img_annotations.iloc[idx,0])
        image = ski.io.imread(img_path)/255   
        image = image[:,:,:3] 
        class_label = self.img_annotations.iloc[idx,2]-1     
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            class_label = self.target_transform(class_label)     
        return image, class_label
    
size = 256
resize = T.Resize(size)
totensor = T.ToTensor()
trans = T.Compose([totensor,resize]) 

train = PetDataset('annotations_aug/annotations_train_O.csv','img_augmented_processed/', transform = trans)
valid = PetDataset('annotations_aug/annotations_valid_O.csv','img_augmented_processed/', transform = trans)
test = PetDataset('annotations_aug/annotations_test_O.csv','img_augmented_processed/', transform = trans)

train_loader = DataLoader(train,batch_size=64,shuffle=True)
valid_loader = DataLoader(valid,batch_size=len(valid),shuffle=True)
test_loader = DataLoader(test,batch_size=len(test),shuffle=True)

# %%
train_b1_img, train_b1_label = next(iter(train_loader))
print('shape of training batch (images): {}'.format(train_b1_img.shape))
print('shape of training batch (labels): {}'.format(train_b1_label.shape))
plt.imshow(train_b1_img[np.random.randint(64)].permute(1,2,0))     #plt.imshow needs the shape to be (x,y,3)
plt.show()
# Out:
# shape of training batch (images): torch.Size([64, 3, 256, 256])
# shape of training batch (labels): torch.Size([64])

# %% [markdown]
# # Model with 6 conv layers

# %%
class PetCNN6ch(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Sequential(
                                    nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=4,stride=2),                                    
                                    nn.BatchNorm2d(8),
                                    nn.ReLU())
        
        self.conv2 = nn.Sequential( nn.Dropout2d(0.2),
                                    nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=4,stride=2),                                    
                                    nn.BatchNorm2d(16),
                                    nn.ReLU())
        
        self.conv3 = nn.Sequential( nn.Dropout2d(0.3),
                                    nn.Conv2d(in_channels=16, out_channels=64, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=3,stride=2),                                    
                                    nn.BatchNorm2d(64),
                                    nn.ReLU())
        
        self.conv4 = nn.Sequential( nn.Dropout2d(0.3),
                                    nn.Conv2d(in_channels=64, out_channels=256, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=3,stride=2),                                    
                                    nn.BatchNorm2d(256),
                                    nn.ReLU())
        
        self.conv5 = nn.Sequential( nn.Dropout(0.3),
                                    nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=3,stride=2),                                    
                                    nn.BatchNorm2d(512),
                                    nn.ReLU())
        
        self.conv6 = nn.Sequential( nn.Dropout(0.4),
                                    nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3),
                                    nn.MaxPool2d(kernel_size=3,stride=1),                                    
                                    nn.BatchNorm2d(1024),
                                    nn.ReLU())
        
        self.dense1 = nn.Sequential(nn.Dropout(0.4),
                                    nn.Linear(1024, 370))
        
        self.dense2 = nn.Sequential(nn.Dropout(0.3),
                                    nn.Linear(370, 37))
                    
        
                       
            
    def forward(self,x):
        out = self.conv1(x)
        out = self.conv2(out)
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.conv5(out)
        out = self.conv6(out)
        out = out.view(out.size(0),-1)     
        out = self.dense1(out)
        out = self.dense2(out)
        out = nn.functional.log_softmax(out,dim=1)    
        
        return out
    


model1 = PetCNN6ch()
loss_function = nn.NLLLoss()


print(model1)
# Out:
# PetCNN6ch(
#   (conv1): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Dropout2d(p=0.2, inplace=False)
#     (1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (2): MaxPool2d(kernel_size=4, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Dropout2d(p=0.3, inplace=False)
#     (1): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1))
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#   )
#   (conv4): Sequential(
#     (0): Dropout2d(p=0.3, inplace=False)
#     (1): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1))
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#   )
#   (conv5): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1))
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#   )
#   (conv6): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1))
#     (2): MaxPool2d(kernel_size=3, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#   )
#   (dense1): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=1024, out_features=370, bias=True)
#   )
#   (dense2): Sequential(
#     (0): Dropout(p=0.3, inplace=False)
#     (1): Linear(in_features=370, out_features=37, bias=True)
#   )
# )

# %%
learning_rate = 0.001
decay_rate = 0.0001
optimizer = torch.optim.Adam(model1.parameters(),lr=learning_rate, weight_decay=decay_rate)

num_epochs = 150

iteration = 0
#iteration_list = []
#train_loss_iter=[]
#train_accuracy_iter=[]
#valid_loss_iter=[]
#valid_accuracy_iter=[]




start = time.time()

#for i in range(num_epochs):
for epoch in range(num_epochs):
    for images, labels in train_loader:
        model1.train()
        out = model1(images.float())
        loss = loss_function(out,labels)
        
        optimizer.zero_grad()
        loss.backward()
        
        #for name, param in model.named_parameters():         # this is just to check if the parameters are getting valid gradients
            #print(name, param.grad.abs().sum())
    
        optimizer.step()
        
        iteration += 1
        
        
        if iteration%50==0:
            
            end = time.time()
            print('Epoch:{}'.format(epoch))
            print('Iteration:{}'.format(iteration))
            print('Time taken for the last 50 iterations: {}'.format(end-start))
            
            
            if epoch>0:      # after the first epoch, every 50th iteration is a checkpoint
                model1.eval()
                with torch.no_grad():
                    train_part = DataLoader(train,batch_size=2048,shuffle=True)   # a random batch from the training set 1
                    images_c, labels_c = next(iter(train_part))
                    train_out = model1(images_c.float())    # we're calculating the training accuracy on this random batch
                    current_train_loss = loss_function(train_out,labels_c)
                    current_train_accuracy = (torch.max(train_out,1)[1]==labels_c).sum()/2048
                    print('Current training loss:{}'.format(current_train_loss))
                    print('Current training accuracy:{}'.format(current_train_accuracy))

                    valid_entire = next(iter(valid_loader))
                    valid_out = model1(valid_entire[0].float())
                    current_valid_loss = loss_function(valid_out,valid_entire[1])
                    current_valid_accuracy = (torch.max(valid_out,1)[1]==valid_entire[1]).sum()/len(valid)
                    print('Current validation loss:{}'.format(current_valid_loss))
                    print('Current validation accuracy:{}'.format(current_valid_accuracy))

                    train_loss_iter.append(current_train_loss)
                    train_accuracy_iter.append(current_train_accuracy)
                    valid_loss_iter.append(current_valid_loss)
                    valid_accuracy_iter.append(current_valid_accuracy)
                    iteration_list.append(iteration)

                
            
            start = time.time()
# Out:
# Epoch:0
# Iteration:50
# Time taken for the last 50 iterations: 65.50493550300598
# Epoch:1
# Iteration:100
# Time taken for the last 50 iterations: 68.59299755096436
# Current training loss:3.563302993774414
# Current training accuracy:0.06298828125
# Current validation loss:3.617192506790161
# Current validation accuracy:0.0555555559694767
# Epoch:1
# Iteration:150
# Time taken for the last 50 iterations: 63.313886404037476
# Current training loss:3.4626271724700928
# Current training accuracy:0.07861328125
# Current validation loss:3.5144643783569336
# Current validation accuracy:0.07222222536802292
# Epoch:2
# Iteration:200
# Time taken for the last 50 iterations: 62.74427604675293
# Current training loss:3.3920559883117676
# Current training accuracy:0.0771484375
# Current validation loss:3.4364824295043945
# Current validation accuracy:0.07222222536802292
# Epoch:2
# Iteration:250
# Time taken for the last 50 iterations: 63.07959985733032
# Current training loss:3.408494234085083
# Current training accuracy:0.0791015625
# Current validation loss:3.4384591579437256
# Current validation accuracy:0.07777778059244156
# Epoch:3
# Iteration:300
# Time taken for the last 50 iterations: 62.3326735496521
# Current training loss:3.4487812519073486
# Current training accuracy:0.07763671875
# Current validation loss:3.520508050918579
# Current validation accuracy:0.08194444328546524
# Epoch:3
# Iteration:350
# Time taken for the last 50 iterations: 62.73529529571533
# Current training loss:3.2809786796569824
# Current training accuracy:0.10400390625
# Current validation loss:3.3354804515838623
# Current validation accuracy:0.0902777761220932
# Epoch:4
# Iteration:400
# Time taken for the last 50 iterations: 62.82370090484619
# Current training loss:3.194868803024292
# Current training accuracy:0.12353515625
# Current validation loss:3.273491382598877
# Current validation accuracy:0.11388888955116272
# Epoch:4
# Iteration:450
# Time taken for the last 50 iterations: 1004.920782327652
# Current training loss:3.2314836978912354
# Current training accuracy:0.11767578125
# Current validation loss:3.337170362472534
# Current validation accuracy:0.11944444477558136
# Epoch:5
# Iteration:500
# Time taken for the last 50 iterations: 61.1143684387207
# Current training loss:3.0688393115997314
# Current training accuracy:0.1572265625
# Current validation loss:3.2389111518859863
# Current validation accuracy:0.11249999701976776
# Epoch:5
# Iteration:550
# Time taken for the last 50 iterations: 63.013083696365356
# Current training loss:3.0944724082946777
# Current training accuracy:0.142578125
# Current validation loss:3.245457172393799
# Current validation accuracy:0.11527777463197708
# Epoch:6
# Iteration:600
# Time taken for the last 50 iterations: 62.61686682701111
# Current training loss:3.088958740234375
# Current training accuracy:0.123046875
# Current validation loss:3.2252893447875977
# Current validation accuracy:0.09305555373430252
# Epoch:6
# Iteration:650
# Time taken for the last 50 iterations: 63.10301661491394
# Current training loss:2.883244514465332
# Current training accuracy:0.19140625
# Current validation loss:3.104419231414795
# Current validation accuracy:0.14722222089767456
# Epoch:7
# Iteration:700
# Time taken for the last 50 iterations: 1535.6710755825043
# Current training loss:2.835907220840454
# Current training accuracy:0.20458984375
# Current validation loss:3.050020694732666
# Current validation accuracy:0.15138888359069824
# Epoch:7
# Iteration:750
# Time taken for the last 50 iterations: 62.69361448287964
# Current training loss:2.760284662246704
# Current training accuracy:0.22705078125
# Current validation loss:2.9939494132995605
# Current validation accuracy:0.16805554926395416
# Epoch:8
# Iteration:800
# Time taken for the last 50 iterations: 62.27764058113098
# Current training loss:2.7214722633361816
# Current training accuracy:0.25830078125
# Current validation loss:2.9643163681030273
# Current validation accuracy:0.17222222685813904
# Epoch:8
# Iteration:850
# Time taken for the last 50 iterations: 63.08620548248291
# Current training loss:2.690662384033203
# Current training accuracy:0.240234375
# Current validation loss:2.976905584335327
# Current validation accuracy:0.1736111044883728
# Epoch:9
# Iteration:900
# Time taken for the last 50 iterations: 62.75406098365784
# Current training loss:2.559465169906616
# Current training accuracy:0.28125
# Current validation loss:2.956486225128174
# Current validation accuracy:0.16944444179534912
# Epoch:9
# Iteration:950
# Time taken for the last 50 iterations: 63.27667045593262
# Current training loss:2.4969799518585205
# Current training accuracy:0.2900390625
# Current validation loss:2.9424712657928467
# Current validation accuracy:0.15833333134651184
# Epoch:10
# Iteration:1000
# Time taken for the last 50 iterations: 61.448760986328125
# Current training loss:2.5801377296447754
# Current training accuracy:0.26611328125
# Current validation loss:2.944201946258545
# Current validation accuracy:0.17777778208255768
# Epoch:10
# Iteration:1050
# Time taken for the last 50 iterations: 62.40842342376709
# Current training loss:2.399662733078003
# Current training accuracy:0.3310546875
# Current validation loss:2.874854803085327
# Current validation accuracy:0.1875
# Epoch:11
# Iteration:1100
# Time taken for the last 50 iterations: 61.470855712890625
# Current training loss:2.3179683685302734
# Current training accuracy:0.35693359375
# Current validation loss:2.8324105739593506
# Current validation accuracy:0.19583334028720856
# Epoch:11
# Iteration:1150
# Time taken for the last 50 iterations: 62.68090033531189
# Current training loss:2.1831748485565186
# Current training accuracy:0.36474609375
# Current validation loss:2.810392141342163
# Current validation accuracy:0.22777777910232544
# Epoch:12
# Iteration:1200
# Time taken for the last 50 iterations: 61.99154472351074
# Current training loss:2.319725275039673
# Current training accuracy:0.34033203125
# Current validation loss:2.9584336280822754
# Current validation accuracy:0.17916665971279144
# Epoch:12
# Iteration:1250
# Time taken for the last 50 iterations: 62.45345139503479
# Current training loss:2.0055830478668213
# Current training accuracy:0.4287109375
# Current validation loss:2.7004692554473877
# Current validation accuracy:0.23888888955116272
# Epoch:13
# Iteration:1300
# Time taken for the last 50 iterations: 61.71483063697815
# Current training loss:2.030184030532837
# Current training accuracy:0.41162109375
# Current validation loss:2.7388179302215576
# Current validation accuracy:0.24166665971279144
# Epoch:13
# Iteration:1350
# Time taken for the last 50 iterations: 62.41020107269287
# Current training loss:2.067007303237915
# Current training accuracy:0.4013671875
# Current validation loss:2.8205621242523193
# Current validation accuracy:0.23194444179534912
# Epoch:14
# Iteration:1400
# Time taken for the last 50 iterations: 61.749661445617676
# Current training loss:1.891602635383606
# Current training accuracy:0.4501953125
# Current validation loss:2.7043302059173584
# Current validation accuracy:0.24722221493721008
# Epoch:14
# Iteration:1450
# Time taken for the last 50 iterations: 62.032851696014404
# Current training loss:1.8033223152160645
# Current training accuracy:0.47900390625
# Current validation loss:2.703904628753662
# Current validation accuracy:0.24722221493721008
# Epoch:15
# Iteration:1500
# Time taken for the last 50 iterations: 61.46555972099304
# Current training loss:1.7523545026779175
# Current training accuracy:0.5
# Current validation loss:2.6876893043518066
# Current validation accuracy:0.23749999701976776
# Epoch:15
# Iteration:1550
# Time taken for the last 50 iterations: 62.09828209877014
# Current training loss:1.6879143714904785
# Current training accuracy:0.5244140625
# Current validation loss:2.654085874557495
# Current validation accuracy:0.2708333432674408
# Epoch:16
# Iteration:1600
# Time taken for the last 50 iterations: 64.7108325958252
# Current training loss:1.4968221187591553
# Current training accuracy:0.58642578125
# Current validation loss:2.6004703044891357
# Current validation accuracy:0.2708333432674408
# Epoch:16
# Iteration:1650
# Time taken for the last 50 iterations: 1507.396639585495
# Current training loss:1.455902338027954
# Current training accuracy:0.6123046875
# Current validation loss:2.575451374053955
# Current validation accuracy:0.2680555582046509
# Epoch:17
# Iteration:1700
# Time taken for the last 50 iterations: 64.67453360557556
# Current training loss:1.3871042728424072
# Current training accuracy:0.61181640625
# Current validation loss:2.527223587036133
# Current validation accuracy:0.28611111640930176
# Epoch:17
# Iteration:1750
# Time taken for the last 50 iterations: 64.18407917022705
# Current training loss:1.3748323917388916
# Current training accuracy:0.6201171875
# Current validation loss:2.6251938343048096
# Current validation accuracy:0.2680555582046509
# Epoch:18
# Iteration:1800
# Time taken for the last 50 iterations: 63.3749897480011
# Current training loss:1.3082584142684937
# Current training accuracy:0.64208984375
# Current validation loss:2.5298871994018555
# Current validation accuracy:0.2874999940395355
# Epoch:18
# Iteration:1850
# Time taken for the last 50 iterations: 64.12883472442627
# Current training loss:1.228453516960144
# Current training accuracy:0.677734375
# Current validation loss:2.6014835834503174
# Current validation accuracy:0.27916666865348816
# Epoch:19
# Iteration:1900
# Time taken for the last 50 iterations: 63.301509380340576
# Current training loss:1.0407401323318481
# Current training accuracy:0.728515625
# Current validation loss:2.5234081745147705
# Current validation accuracy:0.3194444477558136
# Epoch:19
# Iteration:1950
# Time taken for the last 50 iterations: 63.391631841659546
# Current training loss:1.0796231031417847
# Current training accuracy:0.7255859375
# Current validation loss:2.572143793106079
# Current validation accuracy:0.2847222089767456
# Epoch:20
# Iteration:2000
# Time taken for the last 50 iterations: 62.52418088912964
# Current training loss:0.9254195094108582
# Current training accuracy:0.78857421875
# Current validation loss:2.5137078762054443
# Current validation accuracy:0.3152777850627899
# Epoch:20
# Iteration:2050
# Time taken for the last 50 iterations: 62.70901393890381
# Current training loss:0.952964186668396
# Current training accuracy:0.7919921875
# Current validation loss:2.464282989501953
# Current validation accuracy:0.3194444477558136
# Epoch:21
# Iteration:2100
# Time taken for the last 50 iterations: 62.98987317085266
# Current training loss:0.9047459959983826
# Current training accuracy:0.74853515625
# Current validation loss:2.5531885623931885
# Current validation accuracy:0.3055555522441864
# Epoch:21
# Iteration:2150
# Time taken for the last 50 iterations: 63.05424499511719
# Current training loss:0.835783064365387
# Current training accuracy:0.8056640625
# Current validation loss:2.5320122241973877
# Current validation accuracy:0.30694442987442017
# Epoch:22
# Iteration:2200
# Time taken for the last 50 iterations: 932.7952494621277
# Current training loss:0.80638188123703
# Current training accuracy:0.810546875
# Current validation loss:2.492191791534424
# Current validation accuracy:0.3291666805744171
# Epoch:22
# Iteration:2250
# Time taken for the last 50 iterations: 63.98747706413269
# Current training loss:0.7638132572174072
# Current training accuracy:0.818359375
# Current validation loss:2.5187203884124756
# Current validation accuracy:0.33194443583488464
# Epoch:23
# Iteration:2300
# Time taken for the last 50 iterations: 62.79554200172424
# Current training loss:0.7271074652671814
# Current training accuracy:0.8349609375
# Current validation loss:2.4660837650299072
# Current validation accuracy:0.3291666805744171
# Epoch:23
# Iteration:2350
# Time taken for the last 50 iterations: 63.526989221572876
# Current training loss:0.6727361083030701
# Current training accuracy:0.85205078125
# Current validation loss:2.5490050315856934
# Current validation accuracy:0.3097222149372101
# Epoch:24
# Iteration:2400
# Time taken for the last 50 iterations: 62.54152202606201
# Current training loss:0.6246703863143921
# Current training accuracy:0.85498046875
# Current validation loss:2.572514295578003
# Current validation accuracy:0.30694442987442017
# Epoch:24
# Iteration:2450
# Time taken for the last 50 iterations: 63.72963309288025
# Current training loss:0.6213242411613464
# Current training accuracy:0.86669921875
# Current validation loss:2.589853525161743
# Current validation accuracy:0.3097222149372101
# Epoch:25
# Iteration:2500
# Time taken for the last 50 iterations: 62.87415838241577
# Current training loss:0.5981321334838867
# Current training accuracy:0.865234375
# Current validation loss:2.6359426975250244
# Current validation accuracy:0.3125
# Epoch:25
# Iteration:2550
# Time taken for the last 50 iterations: 8962.000206947327
# Current training loss:0.5015741586685181
# Current training accuracy:0.90380859375
# Current validation loss:2.6187283992767334
# Current validation accuracy:0.33194443583488464
# Epoch:26
# Iteration:2600
# Time taken for the last 50 iterations: 65.46468830108643
# Current training loss:0.5078037977218628
# Current training accuracy:0.90380859375
# Current validation loss:2.478215456008911
# Current validation accuracy:0.3472222089767456
# Epoch:26
# Iteration:2650
# Time taken for the last 50 iterations: 75.20355319976807
# Current training loss:0.4511134922504425
# Current training accuracy:0.90771484375
# Current validation loss:2.6833810806274414
# Current validation accuracy:0.31111112236976624
# Epoch:27
# Iteration:2700
# Time taken for the last 50 iterations: 66.07905054092407
# Current training loss:0.40071943402290344
# Current training accuracy:0.9208984375
# Current validation loss:2.638044834136963
# Current validation accuracy:0.31388887763023376
# Epoch:27
# Iteration:2750
# Time taken for the last 50 iterations: 66.89109897613525
# Current training loss:0.3721902072429657
# Current training accuracy:0.943359375
# Current validation loss:2.5336804389953613
# Current validation accuracy:0.34583333134651184
# Epoch:28
# Iteration:2800
# Time taken for the last 50 iterations: 67.24630427360535
# Current training loss:0.37806829810142517
# Current training accuracy:0.9306640625
# Current validation loss:2.5840070247650146
# Current validation accuracy:0.3333333432674408
# Epoch:28
# Iteration:2850
# Time taken for the last 50 iterations: 63.44709014892578
# Current training loss:0.3460466265678406
# Current training accuracy:0.94140625
# Current validation loss:2.5815744400024414
# Current validation accuracy:0.32083332538604736
# Epoch:29
# Iteration:2900
# Time taken for the last 50 iterations: 62.33387994766235
# Current training loss:0.3645716905593872
# Current training accuracy:0.935546875
# Current validation loss:2.585338592529297
# Current validation accuracy:0.3222222328186035
# Epoch:29
# Iteration:2950
# Time taken for the last 50 iterations: 61.35637950897217
# Current training loss:0.32720765471458435
# Current training accuracy:0.9345703125
# Current validation loss:2.595071315765381
# Current validation accuracy:0.3472222089767456
# Epoch:30
# Iteration:3000
# Time taken for the last 50 iterations: 57.16942095756531
# Current training loss:0.3218642473220825
# Current training accuracy:0.93701171875
# Current validation loss:2.7172508239746094
# Current validation accuracy:0.3236111104488373
# Epoch:30
# Iteration:3050
# Time taken for the last 50 iterations: 56.695180892944336
# Current training loss:0.2720004916191101
# Current training accuracy:0.9599609375
# Current validation loss:2.4674291610717773
# Current validation accuracy:0.3583333194255829
# Epoch:31
# Iteration:3100
# Time taken for the last 50 iterations: 69.30053687095642
# Current training loss:0.30705323815345764
# Current training accuracy:0.95263671875
# Current validation loss:2.6026432514190674
# Current validation accuracy:0.3263888955116272
# Epoch:31
# Iteration:3150
# Time taken for the last 50 iterations: 71.33275246620178
# Current training loss:0.24949204921722412
# Current training accuracy:0.96044921875
# Current validation loss:2.665975570678711
# Current validation accuracy:0.3402777910232544
# Epoch:32
# Iteration:3200
# Time taken for the last 50 iterations: 66.77953028678894
# Current training loss:0.2739934027194977
# Current training accuracy:0.95751953125
# Current validation loss:2.6729156970977783
# Current validation accuracy:0.3263888955116272
# Epoch:32
# Iteration:3250
# Time taken for the last 50 iterations: 67.02387404441833
# Current training loss:0.25920116901397705
# Current training accuracy:0.9599609375
# Current validation loss:2.750546455383301
# Current validation accuracy:0.3194444477558136
# Epoch:33
# Iteration:3300
# Time taken for the last 50 iterations: 68.86989259719849
# Current training loss:0.2668488323688507
# Current training accuracy:0.95751953125
# Current validation loss:2.708768844604492
# Current validation accuracy:0.33194443583488464
# Epoch:33
# Iteration:3350
# Time taken for the last 50 iterations: 62.614047050476074
# Current training loss:0.21438884735107422
# Current training accuracy:0.9609375
# Current validation loss:2.6616899967193604
# Current validation accuracy:0.32777777314186096
# Epoch:34
# Iteration:3400
# Time taken for the last 50 iterations: 58.88522529602051
# Current training loss:0.23301561176776886
# Current training accuracy:0.95654296875
# Current validation loss:2.674304485321045
# Current validation accuracy:0.3513889014720917
# Epoch:34
# Iteration:3450
# Time taken for the last 50 iterations: 61.47174525260925
# Current training loss:0.22180777788162231
# Current training accuracy:0.97314453125
# Current validation loss:2.625924587249756
# Current validation accuracy:0.3638888895511627
# Epoch:35
# Iteration:3500
# Time taken for the last 50 iterations: 65.54808497428894
# Current training loss:0.18006525933742523
# Current training accuracy:0.9716796875
# Current validation loss:2.7417516708374023
# Current validation accuracy:0.33888888359069824
# Epoch:35
# Iteration:3550
# Time taken for the last 50 iterations: 61.179991006851196
# Current training loss:0.1911030411720276
# Current training accuracy:0.97900390625
# Current validation loss:2.6289517879486084
# Current validation accuracy:0.3569444417953491
# Epoch:36
# Iteration:3600
# Time taken for the last 50 iterations: 61.36764907836914
# Current training loss:0.19576086103916168
# Current training accuracy:0.97265625
# Current validation loss:2.6890735626220703
# Current validation accuracy:0.3361110985279083
# Epoch:36
# Iteration:3650
# Time taken for the last 50 iterations: 63.01793313026428
# Current training loss:0.15186843276023865
# Current training accuracy:0.98095703125
# Current validation loss:2.72373104095459
# Current validation accuracy:0.35555556416511536
# Epoch:37
# Iteration:3700
# Time taken for the last 50 iterations: 60.14785599708557
# Current training loss:0.17457135021686554
# Current training accuracy:0.9794921875
# Current validation loss:2.660356283187866
# Current validation accuracy:0.33194443583488464
# Epoch:37
# Iteration:3750
# Time taken for the last 50 iterations: 54.967899560928345
# Current training loss:0.15213236212730408
# Current training accuracy:0.9794921875
# Current validation loss:2.696927547454834
# Current validation accuracy:0.3263888955116272
# Epoch:38
# Iteration:3800
# Time taken for the last 50 iterations: 53.18622136116028
# Current training loss:0.13294178247451782
# Current training accuracy:0.9814453125
# Current validation loss:2.705657720565796
# Current validation accuracy:0.3402777910232544
# Epoch:38
# Iteration:3850
# Time taken for the last 50 iterations: 55.914228439331055
# Current training loss:0.15964680910110474
# Current training accuracy:0.9765625
# Current validation loss:2.7203269004821777
# Current validation accuracy:0.3166666626930237
# Epoch:39
# Iteration:3900
# Time taken for the last 50 iterations: 55.710734128952026
# Current training loss:0.1120421290397644
# Current training accuracy:0.98828125
# Current validation loss:2.706408977508545
# Current validation accuracy:0.3430555462837219
# Epoch:39
# Iteration:3950
# Time taken for the last 50 iterations: 57.87885761260986
# Current training loss:0.12868750095367432
# Current training accuracy:0.984375
# Current validation loss:2.7333977222442627
# Current validation accuracy:0.3541666567325592
# Epoch:40
# Iteration:4000
# Time taken for the last 50 iterations: 56.92655539512634
# Current training loss:0.11314690858125687
# Current training accuracy:0.99169921875
# Current validation loss:2.6733436584472656
# Current validation accuracy:0.33888888359069824
# Epoch:40
# Iteration:4050
# Time taken for the last 50 iterations: 56.80234241485596
# Current training loss:0.12734057009220123
# Current training accuracy:0.982421875
# Current validation loss:2.8657307624816895
# Current validation accuracy:0.3236111104488373
# Epoch:41
# Iteration:4100
# Time taken for the last 50 iterations: 54.67662501335144
# Current training loss:0.14857341349124908
# Current training accuracy:0.9794921875
# Current validation loss:2.787437677383423
# Current validation accuracy:0.3333333432674408
# Epoch:41
# Iteration:4150
# Time taken for the last 50 iterations: 57.88583207130432
# Current training loss:0.10453008115291595
# Current training accuracy:0.98779296875
# Current validation loss:2.9126980304718018
# Current validation accuracy:0.3305555582046509
# Epoch:42
# Iteration:4200
# Time taken for the last 50 iterations: 62.254425048828125
# Current training loss:0.09681276977062225
# Current training accuracy:0.9921875
# Current validation loss:2.774205207824707
# Current validation accuracy:0.3611111044883728
# Epoch:42
# Iteration:4250
# Time taken for the last 50 iterations: 62.95906686782837
# Current training loss:0.1270337998867035
# Current training accuracy:0.98974609375
# Current validation loss:2.9560585021972656
# Current validation accuracy:0.3361110985279083
# Epoch:43
# Iteration:4300
# Time taken for the last 50 iterations: 63.999829053878784
# Current training loss:0.10539885610342026
# Current training accuracy:0.98779296875
# Current validation loss:2.7774088382720947
# Current validation accuracy:0.33888888359069824
# Epoch:43
# Iteration:4350
# Time taken for the last 50 iterations: 68.8867769241333
# Current training loss:0.07964114099740982
# Current training accuracy:0.9951171875
# Current validation loss:2.7464420795440674
# Current validation accuracy:0.3430555462837219
# Epoch:44
# Iteration:4400
# Time taken for the last 50 iterations: 69.37169981002808
# Current training loss:0.0954466462135315
# Current training accuracy:0.98974609375
# Current validation loss:2.7595083713531494
# Current validation accuracy:0.3430555462837219
# Epoch:44
# Iteration:4450
# Time taken for the last 50 iterations: 74.60708785057068
# Current training loss:0.08896994590759277
# Current training accuracy:0.9912109375
# Current validation loss:2.6611392498016357
# Current validation accuracy:0.3569444417953491
# Epoch:45
# Iteration:4500
# Time taken for the last 50 iterations: 69.88543677330017
# Current training loss:0.0981370061635971
# Current training accuracy:0.990234375
# Current validation loss:2.6513071060180664
# Current validation accuracy:0.35555556416511536
# Epoch:45
# Iteration:4550
# Time taken for the last 50 iterations: 74.96140050888062
# Current training loss:0.11498250812292099
# Current training accuracy:0.9833984375
# Current validation loss:2.861560344696045
# Current validation accuracy:0.3083333373069763
# Epoch:46
# Iteration:4600
# Time taken for the last 50 iterations: 72.68345141410828
# Current training loss:0.09084388613700867
# Current training accuracy:0.990234375
# Current validation loss:2.8604776859283447
# Current validation accuracy:0.3583333194255829
# Epoch:46
# Iteration:4650
# Time taken for the last 50 iterations: 69.84855580329895
# Current training loss:0.07866742461919785
# Current training accuracy:0.990234375
# Current validation loss:2.875814914703369
# Current validation accuracy:0.34166666865348816
# Epoch:47
# Iteration:4700
# Time taken for the last 50 iterations: 69.12220430374146
# Current training loss:0.08664046227931976
# Current training accuracy:0.9931640625
# Current validation loss:2.865338087081909
# Current validation accuracy:0.34861111640930176
# Epoch:47
# Iteration:4750
# Time taken for the last 50 iterations: 71.12723469734192
# Current training loss:0.08388399332761765
# Current training accuracy:0.9921875
# Current validation loss:2.7513608932495117
# Current validation accuracy:0.35555556416511536
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 20>()
#      24 loss = loss_function(out,labels)
#      26 optimizer.zero_grad()
# ---> 27 loss.backward()
#      29 #for name, param in model.named_parameters():         # this is just to check if the parameters are getting valid gradients
#      30     #print(name, param.grad.abs().sum())
#      32 optimizer.step()
#
# File ~/anaconda3/envs/env_torch/lib/python3.9/site-packages/torch/_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     298 if has_torch_function_unary(self):
#     299     return handle_torch_function(
#     300         Tensor.backward,
#     301         (self,),
#    (...)
#     305         create_graph=create_graph,
#     306         inputs=inputs)
# --> 307 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/anaconda3/envs/env_torch/lib/python3.9/site-packages/torch/autograd/__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     151 if retain_graph is None:
#     152     retain_graph = create_graph
# --> 154 Variable._execution_engine.run_backward(
#     155     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
fig = plt.figure(figsize=(12,6))

loss_graph = fig.add_subplot(1,2,1)
loss_graph.plot(iteration_list, train_loss_iter, 'r-')[0]    # the [0] to get the first element of the tuple returned
loss_graph.plot(iteration_list, valid_loss_iter,'g-')[0]
loss_graph.set_xlabel('iteration')
loss_graph.set_ylabel('loss')
loss_graph.set_xlim(0,5000)
loss_graph.set_ylim(0,5)

acc_graph = fig.add_subplot(1,2,2)
acc_graph.plot(iteration_list,train_accuracy_iter, 'r-')[0]
acc_graph.plot(iteration_list, valid_accuracy_iter,'g-')[0]
acc_graph.set_xlabel('iteration')
acc_graph.set_ylabel('accuracy')
acc_graph.set_xlim(0,5000)
acc_graph.set_ylim(0,1)

plt.show()
